# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import re

# from app.utils.text_extraction import extract_tfidf_keywords, extract_bert_keywords, extract_yake_keywords, extract_rake_keywords, extract_bert_keywords_batch
from app.utils.text import truncate

# %%
# Mockup Data Post
data = {
    "username": "runevil",
    "total_items": 187,
    "elapsed_time_sec": 18.3,
    "data": [
        {
            "Progress": "19/25",
            "id": "52215",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1749/145922.jpg?s=de220aeb9993b641b4aeadf13a99f32a",
            "score": 10,
            "title": "Chi. Chikyuu no Undou ni Tsuite",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "57524",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1332/143513.jpg?s=6837ef969442da4a5c3afb7a3b7fc71c",
            "score": 10,
            "title": "Make Heroine ga Oosugiru!",
            "type": "TV"
        },
        {
            "Progress": "13",
            "id": "33352",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1795/95088.jpg?s=bc34433d3962af2b8aee286add5947e4",
            "score": 10,
            "title": "Violet Evergarden",
            "type": "TV"
        },
        {
            "Progress": "13",
            "id": "37510",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1918/96303.jpg?s=f56b63d6ac3219eb8776460b8f9a3012",
            "score": 10,
            "title": "Mob Psycho 100 II",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "50172",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1228/125011.jpg?s=cfb9e4fcff175cf13cb9c0d0a81dc1dc",
            "score": 10,
            "title": "Mob Psycho 100 III",
            "type": "TV"
        },
        {
            "Progress": "13",
            "id": "46102",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1981/113348.jpg?s=b284c0a47ee5791a005d398ef792b965",
            "score": 10,
            "title": "Odd Taxi",
            "type": "TV"
        },
        {
            "Progress": "24",
            "id": "9253",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1935/127974.jpg?s=82ada9442e8693db63d325f457cf186b",
            "score": 10,
            "title": "Steins;Gate",
            "type": "TV"
        },
        {
            "Progress": "28",
            "id": "52991",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1015/138006.jpg?s=ce1002699d33adc692baf5e3c32e80c1",
            "score": 10,
            "title": "Sousou no Frieren",
            "type": "TV"
        },
        {
            "Progress": "1",
            "id": "28851",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1122/96435.jpg?s=93a12868f53676988803e1d1cd22f1d2",
            "score": 10,
            "title": "Koe no Katachi",
            "type": "Movie"
        },
        {
            "Progress": "64",
            "id": "5114",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1208/94745.jpg?s=21acf8a796b43148e2892f041cd22791",
            "score": 10,
            "title": "Fullmetal Alchemist: Brotherhood",
            "type": "TV"
        },
        {
            "Progress": "11",
            "id": "39535",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1530/117776.jpg?s=2c0d611bea033f393998793b9dca7732",
            "score": 9,
            "title": "Mushoku Tensei: Isekai Ittara Honki Dasu",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "50416",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1518/138730.jpg?s=2ec9024c95d0079ab477fc31c17cab19",
            "score": 9,
            "title": "Skip to Loafer",
            "type": "TV"
        },
        {
            "Progress": "24",
            "id": "54492",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1708/138033.jpg?s=837723ac331e1f11cab5b0d8aefbf0c0",
            "score": 9,
            "title": "Kusuriya no Hitorigoto",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "8525",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/2/43361.jpg?s=eeb9b97ad96958675e805de286cf44c7",
            "score": 9,
            "title": "Kami nomi zo Shiru Sekai",
            "type": "TV"
        },
        {
            "Progress": "25",
            "id": "20583",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/7/76014.jpg?s=b0c0e8075e149dd7e04866cdf50d4c3a",
            "score": 9,
            "title": "Haikyuu!!",
            "type": "TV"
        },
        {
            "Progress": "24",
            "id": "17895",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/12/52091.jpg?s=da5411ff215d58625a8c0ed4168b9297",
            "score": 9,
            "title": "Golden Time",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "32182",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/8/80356.jpg?s=4c98a3ed436e8096e05d8c01d1e63a10",
            "score": 9,
            "title": "Mob Psycho 100",
            "type": "TV"
        },
        {
            "Progress": "25",
            "id": "4224",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/13/22128.jpg?s=84e23cc81f8625834522a098dc86c0b3",
            "score": 9,
            "title": "Toradora!",
            "type": "TV"
        },
        {
            "Progress": "1",
            "id": "16870",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1491/134498.jpg?s=a7e9d53f930ab57f087c62b41793e3df",
            "score": 9,
            "title": "The Last: Naruto the Movie",
            "type": "Movie"
        },
        {
            "Progress": "23",
            "id": "40834",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1347/117616.jpg?s=2917e50f8e02436c61fe06212454bedc",
            "score": 9,
            "title": "Ousama Ranking",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "58502",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1003/146841.jpg?s=02791495532726a696b243704eb1e8f6",
            "score": 9,
            "title": "Zenshuu.",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "37999",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1295/106551.jpg?s=00fc498ed478611aa4320af9e8015c69",
            "score": 8,
            "title": "Kaguya-sama wa Kokurasetai: Tensai-tachi no Renai Zunousen",
            "type": "TV"
        },
        {
            "Progress": "1",
            "id": "16782",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1597/112995.jpg?s=03198bf8c94921f9ab384fcb5b853906",
            "score": 8,
            "title": "Kotonoha no Niwa",
            "type": "Movie"
        },
        {
            "Progress": "12",
            "id": "10080",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/11/30030.jpg?s=69ba99788f2ad8268c25a8072094c486",
            "score": 8,
            "title": "Kami nomi zo Shiru Sekai II",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "52588",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1370/140362.jpg?s=ef043b90d4bf310fcde0a7b070c5d84e",
            "score": 8,
            "title": "Kaijuu 8-gou",
            "type": "TV"
        },
        {
            "Progress": "25",
            "id": "28891",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/9/76662.jpg?s=012bcb820acfabf87751ce3e0db1e7e8",
            "score": 8,
            "title": "Haikyuu!! Second Season",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "31859",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/13/77976.jpg?s=913d9c11ed773cc67e854d9efa8defa0",
            "score": 8,
            "title": "Hai to Gensou no Grimgar",
            "type": "TV"
        },
        {
            "Progress": "13",
            "id": "31964",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/10/78745.jpg?s=844d9959a2cfbc60de12c138ca2837b9",
            "score": 8,
            "title": "Boku no Hero Academia",
            "type": "TV"
        },
        {
            "Progress": "170",
            "id": "34572",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/2/88336.jpg?s=de555da9615451c395c487fbcd3aa715",
            "score": 8,
            "title": "Black Clover",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "47917",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1448/127956.jpg?s=18b1224e7a7b47317fdc79504b5e9c71",
            "score": 8,
            "title": "Bocchi the Rock!",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "31043",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/10/77957.jpg?s=2a823e65b904c9557b2b184f75c69872",
            "score": 8,
            "title": "Boku dake ga Inai Machi",
            "type": "TV"
        },
        {
            "Progress": "25",
            "id": "36456",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1319/92084.jpg?s=90ba2cd72bd9d35f2401aba942a11779",
            "score": 8,
            "title": "Boku no Hero Academia 3rd Season",
            "type": "TV"
        },
        {
            "Progress": "25",
            "id": "33486",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/12/85221.jpg?s=d65251d6fb3c8aea81b25cafeeea52ee",
            "score": 8,
            "title": "Boku no Hero Academia 2nd Season",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "60543",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1721/149001.jpg?s=65264cc282aeddc3cfe0fa8f189fe1b0",
            "score": 8,
            "title": "Dandadan 2nd Season",
            "type": "TV"
        },
        {
            "Progress": "51",
            "id": "35972",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1536/93863.jpg?s=d6e77f1d593044dcebcdec9380e44dab",
            "score": 8,
            "title": "Fairy Tail: Final Series",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "59619",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1329/150512.jpg?s=30cfd6a960d166acb3b04d409c61ecea",
            "score": 8,
            "title": "Ame to Kimi to",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "40591",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1764/106659.jpg?s=9665deb49b34edcd7e6e47620b73d1b3",
            "score": 8,
            "title": "Kaguya-sama wa Kokurasetai? Tensai-tachi no Renai Zunousen",
            "type": "TV"
        },
        {
            "Progress": "24",
            "id": "40748",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1171/109222.jpg?s=31d8a72519f9121c6154b9cb4e45eed1",
            "score": 8,
            "title": "Jujutsu Kaisen",
            "type": "TV"
        },
        {
            "Progress": "22",
            "id": "10793",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1566/133912.jpg?s=c0445d74c5b6bf8c46f623b97fa8beae",
            "score": 8,
            "title": "Guilty Crown",
            "type": "TV"
        },
        {
            "Progress": "1",
            "id": "36098",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1768/93291.jpg?s=efd5378be2e586ce190b7242acb32a49",
            "score": 8,
            "title": "Kimi no Suizou wo Tabetai",
            "type": "Movie"
        },
        {
            "Progress": "12",
            "id": "17549",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/2/51581.jpg?s=529fd7c232635ceec9d6f9382a214402",
            "score": 8,
            "title": "Non Non Biyori",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "55888",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1876/141251.jpg?s=f2f66c5c2903f75be4c965042e4a8975",
            "score": 8,
            "title": "Mushoku Tensei II: Isekai Ittara Honki Dasu Part 2",
            "type": "TV"
        },
        {
            "Progress": "20",
            "id": "18897",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/13/75587.jpg?s=d55218dc232e0441212fb11c69b72468",
            "score": 8,
            "title": "Nisekoi",
            "type": "TV"
        },
        {
            "Progress": "13",
            "id": "56228",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1005/145339.jpg?s=0a44f9de778af2325a37b50b459a2a2b",
            "score": 8,
            "title": "Rekishi ni Nokoru Akujo ni Naru zo",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "53590",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1280/138474.jpg?s=66a8395d6dd08352da7a9a538ab6efbd",
            "score": 8,
            "title": "Saijaku Tamer wa Gomi Hiroi no Tabi wo Hajimemashita.",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "59145",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1155/144299.jpg?s=159c49c711ec5b838a7d323bd4cb2af4",
            "score": 8,
            "title": "Ranma ½ (2024)",
            "type": "TV"
        },
        {
            "Progress": "120",
            "id": "33255",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1973/142750.jpg?s=7df52dc248549c6389ede8f1ac4bda00",
            "score": 8,
            "title": "Saiki Kusuo no Ψ-nan",
            "type": "TV"
        },
        {
            "Progress": "13",
            "id": "59459",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1669/149732.jpg?s=a5b5e593a7f4770b217b76eb3cc775b3",
            "score": 8,
            "title": "Silent Witch: Chinmoku no Majo no Kakushigoto",
            "type": "TV"
        },
        {
            "Progress": "25",
            "id": "11757",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/11/39717.jpg?s=55f88992df908bdcb872db3a398aea49",
            "score": 8,
            "title": "Sword Art Online",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "28677",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/2/73700.jpg?s=a155a2e075df1c241c3d8dd59a4a5898",
            "score": 8,
            "title": "Yamada-kun to 7-nin no Majo",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "22319",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1498/134443.jpg?s=3b5201f5bc801c531f525b99f3adf99c",
            "score": 8,
            "title": "Tokyo Ghoul",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "53516",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1580/141243.jpg?s=1b4c11e7bd7aa3b043147ccc28a59e1c",
            "score": 8,
            "title": "Tensei shitara Dainana Ouji Datta node, Kimama ni Majutsu wo Kiwamemasu",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "39808",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1033/111540.jpg?s=c09329f131b6b49194320696e637ed95",
            "score": 8,
            "title": "Non Non Biyori Nonstop",
            "type": "TV"
        },
        {
            "Progress": "1",
            "id": "60022",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1455/146229.jpg?s=89c7f2caeac02d8401a9d6e1b926801a",
            "score": 8,
            "title": "One Piece Fan Letter",
            "type": "TV Special"
        },
        {
            "Progress": "26",
            "id": "16067",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/7/53549.jpg?s=1db7fe9d7d162e154e4c572c09d8f243",
            "score": 8,
            "title": "Nagi no Asu kara",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "52299",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/

            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/13/85391.jpg?s=e1449a362e3e81a63ff03fb1e963f0e9",
            "score": 6,
            "title": "Fairy Tail Movie 2: Dragon Cry",
            "type": "Movie"
        },
        {
            "Progress": "12",
            "id": "59935",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1714/148317.jpg?s=26a9bb52c7ba435c650793412b36c784",
            "score": 6,
            "title": "Gorilla no Kami kara Kago sareta Reijou wa Ouritsu Kishidan de Kawaigarareru",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "54913",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1212/144711.jpg?s=1f1e2423b8f377b439c470e7899d2803",
            "score": 6,
            "title": "Shinmai Ossan Boukensha, Saikyou Party ni Shinu hodo Kitaerarete Muteki ni Naru.",
            "type": "TV"
        },
        {
            "Progress": "12",
            "id": "57058",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1747/143101.jpg?s=aee8c28b870fe4ce304dd2f5ca7eee85",
            "score": 6,
            "title": "Ore wa Subete wo \"Parry\" suru: Gyaku Kanchigai no Sekai Saikyou wa Boukensha ni Naritai",
            "type": "TV"
        },
        {
            "Progress": "1",
            "id": "50653",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1390/120708.jpg?s=bb00d20ca5e040442af20fd9ff8af1f0",
            "score": 5,
            "title": "Odd Taxi Movie: In the Woods",
            "type": "Movie"
        },
        {
            "Progress": "3/12",
            "id": "51693",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1794/135148.jpg?s=9a5d731c43738e92ef14e5b4d6943562",
            "score": 5,
            "title": "Kaminaki Sekai no Kamisama Katsudou",
            "type": "TV"
        },
        {
            "Progress": "-/12",
            "id": "48569",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1321/117508.jpg?s=acffaeec0b998e5bc836b55b2fe73456",
            "score": 0,
            "title": "86 Part 2",
            "type": "TV"
        },
        {
            "Progress": "-/26",
            "id": "66",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1066/117358.jpg?s=fa0535e04ba5ed4ebf0dafc56fbc4a82",
            "score": 0,
            "title": "Azumanga Daiou The Animation",
            "type": "TV"
        },
        {
            "Progress": "-/12",
            "id": "58600",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1096/147327.jpg?s=2fe8bbb651b0f929df8eb57ada89332d",
            "score": 0,
            "title": "Ameku Takao no Suiri Karte",
            "type": "TV"
        },
        {
            "Progress": "6/12",
            "id": "60162",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1264/152012.jpg?s=8ba2c620dd60dddabde4f1b24c162d4f",
            "score": 0,
            "title": "Akujiki Reijou to Kyouketsu Koushaku",
            "type": "TV"
        },
        {
            "Progress": "-/4",
            "id": "40333",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1207/146272.jpg?s=b222dc44528a2ba0923548a3fd9cf359",
            "score": 0,
            "title": "Uzumaki",
            "type": "TV"
        },
        {
            "Progress": "-/1",
            "id": "34498",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/10/86521.jpg?s=f594734cf2a90d6a79d4c6092fc6b136",
            "score": 0,
            "title": "Uchiage Hanabi, Shita kara Miru ka? Yoko kara Miru ka?",
            "type": "Movie"
        },
        {
            "Progress": "-/12",
            "id": "59131",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1280/143705.jpg?s=da06286066d24c42ff680e58ffbcbb93",
            "score": 0,
            "title": "Tensei Kizoku, Kantei Skill de Nariagaru 2nd Season",
            "type": "TV"
        },
        {
            "Progress": "-/25",
            "id": "47194",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1120/120796.jpg?s=eaf9ba799fb1f94b63897704222b4eb7",
            "score": 0,
            "title": "Summertime Render",
            "type": "TV"
        },
        {
            "Progress": "4/26",
            "id": "50694",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1691/148602.jpg?s=72c8019a0db1fd2d02a1af8c6e3ae6cd",
            "score": 0,
            "title": "Summer Pockets",
            "type": "TV"
        },
        {
            "Progress": "-/25",
            "id": "13125",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1549/136389.jpg?s=dbbdbf8c444ad8a379c939fc199dd007",
            "score": 0,
            "title": "Shinsekai yori",
            "type": "TV"
        },
        {
            "Progress": "2/12",
            "id": "60303",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1163/151246.jpg?s=eff16e5947e7edc1605db2b8fef3064e",
            "score": 0,
            "title": "Shinjiteita Nakama-tachi ni Dungeon Okuchi de Korosarekaketa ga Gift \"Mugen Gacha\" de Level 9999 no Nakama-tachi wo Te ni Irete Moto Party Member to Sekai ni Fukushuu & \"Zamaa!\" Shimasu!",
            "type": "TV"
        },
        {
            "Progress": "-/11",
            "id": "44074",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1135/114867.jpg?s=6b933d329f339f473dddd2cd306612ab",
            "score": 0,
            "title": "Shiguang Dailiren",
            "type": "ONA"
        },
        {
            "Progress": "-/12",
            "id": "53770",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1183/141489.jpg?s=cc06161392e55b3c221857f932682f28",
            "score": 0,
            "title": "Sentai Daishikkaku",
            "type": "TV"
        },
        {
            "Progress": "1/11",
            "id": "58939",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1026/146459.jpg?s=88c3ae866e77a509c01d753ae1b66f2f",
            "score": 0,
            "title": "Sakamoto Days",
            "type": "TV"
        },
        {
            "Progress": "-/11",
            "id": "30727",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/2/84797.jpg?s=c38f15efa52e68a002acbe306a9a4928",
            "score": 0,
            "title": "Saenai Heroine no Sodatekata ♭",
            "type": "TV"
        },
        {
            "Progress": "-/12",
            "id": "23277",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1329/142757.jpg?s=9b17fe61f3cda52495fdfa2aff02aa72",
            "score": 0,
            "title": "Saenai Heroine no Sodatekata",
            "type": "TV"
        },
        {
            "Progress": "1/-",
            "id": "60564",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1011/152084.jpg?s=db0693622494eefea08408c90e3a2ab9",
            "score": 0,
            "title": "Ranma ½ (2024) 2nd Season",
            "type": "TV"
        },
        {
            "Progress": "2/24",
            "id": "51297",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1763/140359.jpg?s=2bb25af6d5d8823022b4d342d29577c1",
            "score": 0,
            "title": "Ragna Crimson",
            "type": "TV"
        },
        {
            "Progress": "-/1",
            "id": "437",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1254/134212.jpg?s=698d4458869274bd136e46616190fe84",
            "score": 0,
            "title": "Perfect Blue",
            "type": "Movie"
        },
        {
            "Progress": "-/60",
            "id": "50955",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1278/120805.jpg?s=e88d0a89e56890403c9e5d9b895df3e8",
            "score": 0,
            "title": "Onipan!",
            "type": "TV"
        },
        {
            "Progress": "-/26",
            "id": "10165",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/3/75617.jpg?s=6004e5383a66517fa40fb0d63aa27ae6",
            "score": 0,
            "title": "Nichijou",
            "type": "TV"
        },
        {
            "Progress": "4/12",
            "id": "56854",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1721/151097.jpg?s=895272d7af93240f4bbadf463a30fef2",
            "score": 0,
            "title": "Mushoku no Eiyuu: Betsu ni Skill Nanka Iranakatta n da ga",
            "type": "TV"
        },
        {
            "Progress": "-/18",
            "id": "38903",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1181/148693.jpg?s=ae6492eca1e2071779769e5240092a3a",
            "score": 0,
            "title": "Moonrise",
            "type": "ONA"
        },
        {
            "Progress": "-/74",
            "id": "19",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/10/18793.jpg?s=b467d33eb4db2d9babfd02538c35c795",
            "score": 0,
            "title": "Monster",
            "type": "TV"
        },
        {
            "Progress": "5/12",
            "id": "61276",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/

            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1002/138524.jpg?s=f90473902a7b2d15fd533f437a763d92",
            "score": 0,
            "title": "Helck",
            "type": "TV"
        },
        {
            "Progress": "-/12",
            "id": "59002",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1703/146128.jpg?s=fee96b768c60a28ec2d12f3729b7ae4f",
            "score": 0,
            "title": "Hazure Skill \"Kinomi Master\": Skill no Mi (Tabetara Shinu) wo Mugen ni Taberareru You ni Natta Ken ni Tsuite",
            "type": "TV"
        },
        {
            "Progress": "-/23",
            "id": "40052",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1418/107954.jpg?s=d08a85330ec26b54b0f0078627061f09",
            "score": 0,
            "title": "Great Pretender",
            "type": "TV"
        },
        {
            "Progress": "1/12",
            "id": "54968",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1607/143547.jpg?s=67076969f4aec9da8116dcc4d16cbd47",
            "score": 0,
            "title": "Giji Harem",
            "type": "TV"
        },
        {
            "Progress": "5/24",
            "id": "59062",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1682/150432.jpg?s=c9b6dd643dab40516950d9e261903c91",
            "score": 0,
            "title": "Gachiakuta",
            "type": "TV"
        },
        {
            "Progress": "1/12",
            "id": "59113",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1406/146839.jpg?s=5307a0c68f386f1904ec8020e2a78c4a",
            "score": 0,
            "title": "Farmagia",
            "type": "TV"
        },
        {
            "Progress": "2/24",
            "id": "52701",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1711/142478.jpg?s=f3493d93a2fa26c2aacbd22cb2bec4e0",
            "score": 0,
            "title": "Dungeon Meshi",
            "type": "TV"
        },
        {
            "Progress": "-/13",
            "id": "16592",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/4/51463.jpg?s=3c1be328e970975e03783f200e76bbac",
            "score": 0,
            "title": "Danganronpa: Kibou no Gakuen to Zetsubou no Koukousei The Animation",
            "type": "TV"
        },
        {
            "Progress": "-/1",
            "id": "8142",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1839/103426.jpg?s=45902b1185300378cce0ba41577e981f",
            "score": 0,
            "title": "Colorful (Movie)",
            "type": "Movie"
        },
        {
            "Progress": "10/25",
            "id": "1575",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1032/135088.jpg?s=7fc91a20b4351859f589ae8cddcbbd91",
            "score": 0,
            "title": "Code Geass: Hangyaku no Lelouch",
            "type": "TV"
        },
        {
            "Progress": "-/12",
            "id": "59205",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1255/150593.jpg?s=53768233102bb06ca06424234552ca0a",
            "score": 0,
            "title": "Clevatess: Majuu no Ou to Akago to Shikabane no Yuusha",
            "type": "TV"
        },
        {
            "Progress": "2/13",
            "id": "59517",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1015/151233.jpg?s=e96ab7975038e8b1f77f0ab9717d4f37",
            "score": 0,
            "title": "Chitose-kun wa Ramune Bin no Naka",
            "type": "TV"
        },
        {
            "Progress": "-/11",
            "id": "41457",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1987/117507.jpg?s=e1010a97842dc7016aab99b2bafcf240",
            "score": 0,
            "title": "86",
            "type": "TV"
        },
        {
            "Progress": "-/12",
            "id": "21405",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1257/145479.jpg?s=d8bcf1a94badc1af56f1c147bf8f2472",
            "score": 0,
            "title": "Bokura wa Minna Kawai-sou",
            "type": "TV"
        },
        {
            "Progress": "-/13",
            "id": "55690",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1643/138581.jpg?s=8252809dd5bef67a0656af6870774354",
            "score": 0,
            "title": "Boku no Kokoro no Yabai Yatsu 2nd Season",
            "type": "TV"
        },
        {
            "Progress": "-/12",
            "id": "52578",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1545/133887.jpg?s=d4dc8d3d5928e75c79bbfb5e62567beb",
            "score": 0,
            "title": "Boku no Kokoro no Yabai Yatsu",
            "type": "TV"
        },
        {
            "Progress": "3/12",
            "id": "61026",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1276/151118.jpg?s=03bbabd39c771dc13b64c3b0e0867b69",
            "score": 0,
            "title": "Ansatsusha de Aru Ore no Status ga Yuusha yori mo Akiraka ni Tsuyoi no da ga",
            "type": "TV"
        },
        {
            "Progress": "9/13",
            "id": "60593",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1538/148604.jpg?s=8eadaa5550395752338d2c04c589d3fd",
            "score": 0,
            "title": "Vigilante: Boku no Hero Academia Illegals",
            "type": "TV"
        },
        {
            "Progress": "-/12",
            "id": "59623",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1104/151524.jpg?s=a62eff0c71b6f852e59163d42c6da645",
            "score": 0,
            "title": "Wandance",
            "type": "TV"
        },
        {
            "Progress": "-/12",
            "id": "43299",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1079/110751.jpg?s=58959497ea48724fbcfdf9bd20a79b51",
            "score": 0,
            "title": "Wonder Egg Priority",
            "type": "TV"
        },
        {
            "Progress": "3/12",
            "id": "53632",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1239/134810.jpg?s=0a0c01b2a793bdeac4e7fd7f8c60be05",
            "score": 0,
            "title": "Yumemiru Danshi wa Genjitsushugisha",
            "type": "TV"
        },
        {
            "Progress": "7/25",
            "id": "59597",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1526/150689.jpg?s=532b16d68a5a0a5e68e659125e2d678c",
            "score": 0,
            "title": "Witch Watch",
            "type": "TV"
        },
        {
            "Progress": "-/-",
            "id": "61758",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1529/150295.jpg?s=889fba22a457d9578ae6f9712d74880c",
            "score": 0,
            "title": "Akuyaku Reijou no Naka no Hito",
            "type": "Unknown"
        },
        {
            "Progress": "-/12",
            "id": "58216",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1647/146961.jpg?s=877f4726867f7ff5764b847835fbd93b",
            "score": 0,
            "title": "Übel Blatt",
            "type": "TV"
        },
        {
            "Progress": "-/10",
            "id": "42310",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1818/126435.jpg?s=0be17183a1db49a9a2fb43affb404d81",
            "score": 0,
            "title": "Cyberpunk: Edgerunners",
            "type": "ONA"
        },
        {
            "Progress": "-/1",
            "id": "21329",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1559/147521.jpg?s=adfbf9de88be2f85e81584087c4e543c",
            "score": 0,
            "title": "Mushishi: Hihamukage",
            "type": "TV Special"
        },
        {
            "Progress": "-/12",
            "id": "60146",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1712/148299.jpg?s=442bd371e9231ce6adb078886e2c22de",
            "score": 0,
            "title": "Saikyou no Ousama, Nidome no Jinsei wa Nani wo Suru?",
            "type": "TV"
        },
        {
            "Progress": "-/-",
            "id": "59741",
            "image": "https://cdn.myanimelist.net/r/192x272/images/anime/1502/145271.jpg?s=ac707353eeed15775a5235d1ce177e62",
            "score": 0,
            "title": "Tsuihou sareta Tensei Juukishi wa Game Chishiki de Musou suru",
            "type": "TV"
        }
    ]
}

# %%
df = pd.DataFrame(data["data"])
df.rename(columns={'id': 'mal_id'}, inplace=True)
df.rename(columns={'score': 'my_score'}, inplace=True)

# %%
file_path = './app/static/data/dataset.csv'
dataset = pd.read_csv(file_path)

# %%
# set type mal_id
df['mal_id'] = pd.to_numeric(df['mal_id'], errors='coerce')
dataset['mal_id'] = pd.to_numeric(dataset['mal_id'], errors='coerce')

# drop duplicate colomns
cols_to_drop = [col for col in df.columns if col in dataset.columns and col != 'mal_id']
df_clean = dataset.drop(columns=cols_to_drop+['image_url'])

merged_df = pd.merge(df, df_clean, on='mal_id', how='inner')
merged_df = merged_df.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# ### Remove Unwatched

# %% [markdown]
# ### Studio

# %%
merged_df['studio'] = (merged_df['studio'].str.split(',').explode().str.strip().groupby(level=0).agg(list))
merged_df['studio'] = merged_df['studio'].apply(lambda x: eval(x) if isinstance(x, str) else x)

studio_df = merged_df.explode('studio')['studio'].value_counts().reset_index()
studio_df.columns = ['studios', 'count']
print(studio_df.head(5).to_markdown())
# Out:
# |    | studios      |   count |
# |---:|:-------------|--------:|
# |  0 | A-1 Pictures |      19 |
# |  1 | Madhouse     |       9 |
# |  2 | Bones        |       9 |
# |  3 | SILVER LINK. |       9 |
# |  4 | OLM          |       7 |

# %% [markdown]
# ### Genre

# %%
merged_df['genre'] = (merged_df['genre'].str.split(',').explode().str.strip().groupby(level=0).agg(list))
merged_df['genre'] = merged_df['genre'].apply(lambda x: eval(x) if isinstance(x, str) else x)

genre_df = merged_df.explode('genre')['genre'].value_counts().reset_index()
genre_df.columns = ['genres', 'count']
print(genre_df.head(5).to_markdown())
# Out:
# |    | genres   |   count |
# |---:|:---------|--------:|
# |  0 | Fantasy  |      73 |
# |  1 | Action   |      71 |
# |  2 | Romance  |      58 |
# |  3 | School   |      57 |
# |  4 | Comedy   |      54 |

# %% [markdown]
# ### Producer

# %%
merged_df['producer'] = (merged_df['producer'].str.split(',').explode().str.strip().groupby(level=0).agg(list))
merged_df['producer'] = merged_df['producer'].apply(lambda x: eval(x) if isinstance(x, str) else x)

producer_df = merged_df.explode('producer')['producer'].value_counts().reset_index()
producer_df.columns = ['producers', 'count']
print(producer_df.head(5).to_markdown())
# Out:
# |    | producers                    |   count |
# |---:|:-----------------------------|--------:|
# |  0 | Aniplex                      |      41 |
# |  1 | Movic                        |      31 |
# |  2 | Shueisha                     |      29 |
# |  3 | Dentsu                       |      28 |
# |  4 | Mainichi Broadcasting System |      27 |

# %% [markdown]
# ### Keyword

# %%
merged_df['keywords'] = merged_df['keywords'].str.split(', ')
merged_df['keywords'] = merged_df['keywords'].apply(lambda x: eval(x) if isinstance(x, str) else x)

keywords_df = merged_df.explode('keywords')['keywords'].value_counts().reset_index()
keywords_df.columns = ['keywords', 'count']
print(keywords_df.head(5).to_markdown())
# Out:
# |    | keywords     |   count |
# |---:|:-------------|--------:|
# |  0 | student      |      17 |
# |  1 | death        |      14 |
# |  2 | supernatural |      12 |
# |  3 | friends      |      12 |
# |  4 | monsters     |      12 |

# %% [markdown]
# ### Demographic

# %%
df['demographic'] = (merged_df['demographic'].str.split(',').explode().str.strip().groupby(level=0).agg(list))
df['demographic'] = df['demographic'].apply(lambda x: eval(x) if isinstance(x, str) else x)

demographic_df = df.explode('demographic')['demographic'].value_counts().reset_index()
demographic_df.columns = ['demographics', 'count']
demographic_df = demographic_df[demographic_df['demographics'] != '-']

print(demographic_df.to_markdown())
# Out:
# |    | demographic   |   count |
# |---:|:--------------|--------:|
# |  0 | Shounen       |      48 |
# |  1 | Seinen        |      23 |
# |  2 | Shoujo        |       4 |
# |  3 | Josei         |       2 |
# |  4 | Kids          |       0 |

# %% [markdown]
# ### Theme

# %%
merged_df['theme'] = merged_df['theme'].str.split(', ')
merged_df['theme'] = merged_df['theme'].apply(lambda x: eval(x) if isinstance(x, str) else x)

theme_df = merged_df.explode('theme')['theme'].value_counts().reset_index()
theme_df.columns = ['themes', 'count']
theme_df = theme_df[theme_df['themes'] != '-']

print(theme_df.head(5).to_markdown())
# Out:
# |    | themes        |   count |
# |---:|:--------------|--------:|
# |  1 | School        |      16 |
# |  2 | Isekai        |       5 |
# |  3 | Psychological |       3 |
# |  4 | Urban Fantasy |       2 |
# |  5 | Historical    |       2 |

# %% [markdown]
# ### Time Analysis

# %%
df = merged_df.copy()
df['premiered'] = (df['premiered'].str.replace('  ', ' ', regex=False).str.strip())
df = df[~df['premiered'].isin(['-', '?'])]
df['season'] = df['premiered'].str.extract(r'^(Fall|Spring|Summer|Winter)')
df['year'] = df['premiered'].str.extract(r'(\d{4})')
df = df.dropna(subset=['season', 'year'])
count_df = (df.groupby(['year', 'season']).size().reset_index(name='count'))
season_order = ['Fall', 'Spring', 'Summer', 'Winter']
full_index = pd.MultiIndex.from_product([count_df['year'].unique(), season_order],names=['year', 'season'])

final_df = (count_df.set_index(['year', 'season']).reindex(full_index, fill_value=0).reset_index())
final_df['time'] = final_df['season'] + ' ' + final_df['year']
final_df['season'] = pd.Categorical(final_df['season'],categories=season_order,ordered=True)

final_df = final_df.sort_values(['year', 'season'])
time_df = final_df[['time', 'count']].reset_index()
time_df = time_df.drop(columns=['index'])

print(time_df.to_markdown())
# Out:
# |    | time        |   count |
# |---:|:------------|--------:|
# |  0 | Fall 1999   |       1 |
# |  1 | Spring 1999 |       0 |
# |  2 | Summer 1999 |       0 |
# |  3 | Winter 1999 |       0 |
# |  4 | Fall 2002   |       0 |
# |  5 | Spring 2002 |       1 |
# |  6 | Summer 2002 |       0 |
# |  7 | Winter 2002 |       0 |
# |  8 | Fall 2004   |       0 |
# |  9 | Spring 2004 |       1 |
# | 10 | Summer 2004 |       0 |
# | 11 | Winter 2004 |       0 |
# | 12 | Fall 2006   |       1 |
# | 13 | Spring 2006 |       0 |
# | 14 | Summer 2006 |       0 |
# | 15 | Winter 2006 |       0 |
# | 16 | Fall 2008   |       1 |
# | 17 | Spring 2008 |       0 |
# | 18 | Summer 2008 |       0 |
# | 19 | Winter 2008 |       0 |
# | 20 | Fall 2009   |       1 |
# | 21 | Spring 2009 |       1 |
# | 22 | Summer 2009 |       0 |
# | 23 | Winter 2009 |       0 |
# | 24 | Fall 2010   |       1 |
# | 25 | Spring 2010 |       0 |
# | 26 | Summer 2010 |       0 |
# | 27 | Winter 2010 |       0 |
# ...

# %% [markdown]
# # Analysis Content Based Filtering

# %%
print(merged_df.applymap(truncate).to_markdown())
# Out:
# |     | Progress   |   mal_id | image                   |   my_score | title                   | type       | id                      | synopsis                | aired                 | premiered   |   member |   favorite | source       | rank   | link                    | episode   | genre                                                                                                        | producer                                                                                                                                                                                                                                            | studio                                    | theme                    | demographic   | duration        | rating                | score   | count_user_score   | keywords                                                                                                                                         |
# ...
